# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\elizabeth\Documents\Luca's scraping\cyber_friends_tweets_subset_0.csv")

# %%
#preprocessing - first glanses at the data 
column_names = list(df.columns)
unique_values = list()
for col in df:
    unique_values.append(df[col].unique())
number_unique_values = list()
for col in df:
    number_unique_values.append(len(df[col].unique()))

#a summary table fo unique information 
summary_table = pd.DataFrame(column_names)
summary_table.columns=['column names']
summary_table['unique values'] = unique_values
summary_table['number of unique values'] = number_unique_values
summary_table
# Out:
#                column names  \
# 0                   user_id
# 1               screen_name
# 2                      name
# 3                  tweet_id
# 4                      text
# 5          tweet_created_at
# 6           conversation_id
# 7     in_reply_to_status_id
# 8                     rt_id
# 9                rt_user_id
# 10           rt_screen_name
# 11                  rt_text
# 12      in_reply_to_user_id
# 13  in_reply_to_screen_name
# 14         quoted_status_id
# 15            quoted_status
# 16            replies_count
# 17            retweet_count
# 18               like_count
# 19                 hashtags
#
#                                         unique values  number of unique values
# 0   [363675945, 2546033492, 179178993, 1325420790,...                      469
# 1   [robahusseini, hashemosseiran, liveanthony, el...                      469
# 2   [Roba El Husseini ربى, Hashem Osseiran, Anthon...                      469
# 3   [1294203275043110912, 1293934001514848256, 129...                    90345
# 4   [Beirut blast who knew what when My latest for...                    83449
# 5   [2020-08-14 09:24:40, 2020-08-13 15:34:40, 202...                    88642
# 6                                               [nan]                        1
# 7   [nan, 1.291313553488728e+18, 1.291307740959129...                    29054
# 8   [nan, 1.2939186412561654e+18, 1.29358045553567...                    27499
# 9   [nan, 546784195.0, 9.725362932164484e+17, 2517...                    13291
# 10  [nan, layalafp, afp_beirut, drmaramalsheikh, l...                    13291
# 11  [None, Breaking via FBI to join Beirut blast p...                    26936
# 12  [nan, 363675945.0, 108524355.0, 9.725362932164...                    15700
# 13  [nan, robahusseini, mutludc, afp_beirut, afp_m...                    15704
# 14  [nan, 1.2905553362235924e+18, 1.28765218958282...                    10715
# 15  [nan, Status(_json={'created_at': 'Thu Jun 04 ...                     7298
# 16                                              [nan]                        1
# 17  [22, 17, 8, 9, 7, 359, 116, 0, 15, 1, 2, 5, 16...                     4675
# 18  [38, 0, 12, 7, 8, 1, 3, 13, 2, 9, 28, 4, 14, 1...                     3295
# 19  [[], ['breaking', 'fbi', 'beirut', 'probe'], [...                     6141

# %%
df_like_count = df.groupby('screen_name')[['retweet_count', 'like_count']].sum()
df_number_tweets = df.groupby('screen_name')['text'].count()
df_like_count['number_tweets'] = df_number_tweets

# %%
df2 = pd.read_csv(r"C:\Users\elizabeth\Documents\Luca's scraping\education_user_profiles.csv")
#preprocessing - first glanses at the data 
column_names = list(df.columns)
unique_values = list()
for col in df:
    unique_values.append(df[col].unique())
number_unique_values = list()
for col in df:
    number_unique_values.append(len(df[col].unique()))

#a summary table fo unique information 
summary_table = pd.DataFrame(column_names)
summary_table.columns=['column names']
summary_table['unique values'] = unique_values
summary_table['number of unique values'] = number_unique_values
summary_table
# Out:
#                column names  \
# 0                   user_id
# 1               screen_name
# 2                      name
# 3                  tweet_id
# 4                      text
# 5          tweet_created_at
# 6           conversation_id
# 7     in_reply_to_status_id
# 8                     rt_id
# 9                rt_user_id
# 10           rt_screen_name
# 11                  rt_text
# 12      in_reply_to_user_id
# 13  in_reply_to_screen_name
# 14         quoted_status_id
# 15            quoted_status
# 16            replies_count
# 17            retweet_count
# 18               like_count
# 19                 hashtags
#
#                                         unique values  number of unique values
# 0   [363675945, 2546033492, 179178993, 1325420790,...                      469
# 1   [robahusseini, hashemosseiran, liveanthony, el...                      469
# 2   [Roba El Husseini ربى, Hashem Osseiran, Anthon...                      469
# 3   [1294203275043110912, 1293934001514848256, 129...                    90345
# 4   [Beirut blast who knew what when My latest for...                    83449
# 5   [2020-08-14 09:24:40, 2020-08-13 15:34:40, 202...                    88642
# 6                                               [nan]                        1
# 7   [nan, 1.291313553488728e+18, 1.291307740959129...                    29054
# 8   [nan, 1.2939186412561654e+18, 1.29358045553567...                    27499
# 9   [nan, 546784195.0, 9.725362932164484e+17, 2517...                    13291
# 10  [nan, layalafp, afp_beirut, drmaramalsheikh, l...                    13291
# 11  [None, Breaking via FBI to join Beirut blast p...                    26936
# 12  [nan, 363675945.0, 108524355.0, 9.725362932164...                    15700
# 13  [nan, robahusseini, mutludc, afp_beirut, afp_m...                    15704
# 14  [nan, 1.2905553362235924e+18, 1.28765218958282...                    10715
# 15  [nan, Status(_json={'created_at': 'Thu Jun 04 ...                     7298
# 16                                              [nan]                        1
# 17  [22, 17, 8, 9, 7, 359, 116, 0, 15, 1, 2, 5, 16...                     4675
# 18  [38, 0, 12, 7, 8, 1, 3, 13, 2, 9, 28, 4, 14, 1...                     3295
# 19  [[], ['breaking', 'fbi', 'beirut', 'probe'], [...                     6141

# %%
df_user_metrics = pd.merge(df2, df_like_count, how='inner', on='screen_name')
df_user_metrics.head()
# Out:
#       user_id      screen_name            name      location  \
# 0    14642495         sarahcpr    Sarah Cooper  Brooklyn, NY
# 1   140149359      khalafroula    roula khalaf        London
# 2    93222172  mrmichaelspicer  Michael Spicer  Kent, London
# 3  2176527421    philippullman  Philip Pullman           NaN
# 4    69080476        pickardje     Jim Pickard        London
#
#                                     user_description  user_friends_n  \
# 0  writer / comedian / #blockedbytrump / wrote 10...            2990
# 1  Editor of the Financial Times, fan of impossib...            1839
# 2                             the room next door man            1822
# 3  Writer (His Dark Materials, etc). Read like a ...             727
# 4     Chief Political Correspondent, Financial Times            4486
#
#    user_followers_n      prof_created_at  favourites_count  verified  \
# 0           2221914  2008-05-03 23:30:29            139163      True
# 1             45541  2010-05-04 18:40:46              1753      True
# 2            367522  2009-11-28 17:19:58             41224      True
# 3            176442  2013-11-05 17:53:58               910      True
# 4            142536  2009-08-26 20:06:27             56461      True
#
#    statuses_count  retweet_count  like_count  number_tweets
# 0           37518        2008608     6022477            200
# 1            5129          10995       20140            200
# 2           29098          99330      523603            177
# 3           11290          22841       48671            200
# 4           48368         227555       74841            197

# %%
import matplotlib.pyplot as plt

plt.scatter(df_user_metrics['retweet_count'], df_user_metrics['like_count'])
plt.yscale('log')
plt.xscale('log')
plt.ylabel('Number of likes')
plt.xlabel('Number retweets')
# Out:
# Text(0.5, 0, 'Number retweets')

# %%
df_user_metrics['norm_likes'] = (df_user_metrics['like_count'] /
                                        df_user_metrics['number_tweets'])
df_user_metrics['norm_retweet'] = (df_user_metrics['retweet_count'] /
                                        df_user_metrics['number_tweets'])

# %% [markdown]
# # h-index likes and retweets

# %%
df['retweets&likes'] = df['retweet_count'] + df['like_count']

def hindex(citations):
    """
    :type citations: List[int]
    :rtype: int
    """
    citations = sorted(citations, reverse=True)
    for idx, item in enumerate(citations, 1):
        if item < idx:
            break
    return idx - 1

hdict = {}
for user_name in list(df['screen_name'].unique()):
    like_list = list(df[df['screen_name']==user_name]['retweets&likes'].values)
    h= hindex(like_list)
    hdict[user_name]=h

hdict = {k: v for k, v in sorted(hdict.items(), key=lambda item: item[1], reverse=True)}

# %%
hdict_df = pd.DataFrame(hdict.items())
hdict_df.columns = ['screen_name', 'h-index_like&retweets']
df_user_metrics = pd.merge(df_user_metrics, hdict_df, how='inner', on='screen_name')

df_user_metrics
# Out:
#        user_id      screen_name                                name  \
# 0     14642495         sarahcpr                        Sarah Cooper
# 1    140149359      khalafroula                        roula khalaf
# 2     93222172  mrmichaelspicer                      Michael Spicer
# 3   2176527421    philippullman                      Philip Pullman
# 4     69080476        pickardje                         Jim Pickard
# ..         ...              ...                                 ...
# 81    17945263     danrebellato                       Dan Rebellato
# 82    98047213           huawei                              Huawei
# 83   386056280       marawilson  Mara “Get Rid of the Nazis” Wilson
# 84  1075005146       hegghammer                   Thomas Hegghammer
# 85    26259576         jonnysun                           jonny sun
#
#                    location  \
# 0              Brooklyn, NY
# 1                    London
# 2              Kent, London
# 3                       NaN
# 4                    London
# ..                      ...
# 81  Lambeth, Greater London
# 82                      NaN
# 83             L.A., mostly
# 84             Oslo, Norway
# 85                      NaN
#
#                                      user_description  user_friends_n  \
# 0   writer / comedian / #blockedbytrump / wrote 10...            2990
# 1   Editor of the Financial Times, fan of impossib...            1839
# 2                              the room next door man            1822
# 3   Writer (His Dark Materials, etc). Read like a ...             727
# 4      Chief Political Correspondent, Financial Times            4486
# ..                                                ...             ...
# 81        world-renowned playwright and exotic dancer            2066
# 82  Welcome to the official Huawei Twitter account...            1000
# 83  Ask your niece/daughter/librarian who I am. Bu...            6195
# 84  Senior research fellow at Norwegian Defence Re...             725
# 85  screenwriter, author, artist! books: everyone’...            2640
#
#     user_followers_n      prof_created_at  favourites_count  verified  \
# 0            2221914  2008-05-03 23:30:29            139163      True
# 1              45541  2010-05-04 18:40:46              1753      True
# 2             367522  2009-11-28 17:19:58             41224      True
# 3             176442  2013-11-05 17:53:58               910      True
# 4             142536  2009-08-26 20:06:27             56461      True
# ..               ...                  ...               ...       ...
# 81             18514  2008-12-07 18:34:41             46596      True
# 82           4640581  2009-12-20 04:20:07              7172      True
# 83            572349  2011-10-06 16:00:46            319234      True
# 84             27403  2013-01-09 21:56:05             22912     False
# 85            582866  2009-03-24 15:42:07            260209      True
#
#     statuses_count  retweet_count  like_count  number_tweets    norm_likes  \
# 0            37518        2008608     6022477            200  30112.385000
# 1             5129          10995       20140            200    100.700000
# 2            29098          99330      523603            177   2958.209040
# 3            11290          22841       48671            200    243.355000
# 4            48368         227555       74841            197    379.903553
# ..             ...            ...         ...            ...           ...
# 81          109384         306294        2840            191     14.869110
# 82           23886           1285        7746            200     38.730000
# 83          154951         199481       32035            200    160.175000
# 84           14802         303783        1825            197      9.263959
# 85           50522         743322      239361            182   1315.170330
#
#     norm_retweet  h-index_like&retweets_x  h-index_like&retweets_y
# 0   10043.040000                      191                      191
# 1      54.975000                       52                       52
# 2     561.186441                       91                       91
# 3     114.205000                       53                       53
# 4    1155.101523                      114                      114
# ..           ...                      ...                      ...
# 81   1603.633508                       39                       39
# 82      6.425000                       32                       32
# 83    997.405000                      106                      106
# 84   1542.045685                       69                       69
# 85   4084.186813                       84                       84
#
# [86 rows x 18 columns]

# %%
df_user_metrics_sorted = df_user_metrics.sort_values(['h-index_like&retweets_x'], ascending=False)
df_user_metrics_sorted_subset = df_user_metrics_sorted[0:19]
ax = df_user_metrics_sorted_subset.plot.barh(x='screen_name', y='h-index_like&retweets_x')

# %%
import os
import sys
import time
import datetime
import json
import pandas as pd

import tweepy

sys.path.insert(1, '../')
from src.data import journalists as journos
from src.data.api_tweepy import connect_API
from src.data.api_user_tools import query_user_relationship, batch_request_user_info

# %%
api_keys_fp = '../data/twitter_credentials.json'
tw_api = connect_API(api_keys_fp)

# %%
trial = tw_api.show_friendship(source_screen_name='kimknilsson', target_screen_name='jlesliedata')

# %%
output = query_user_relationship(tw_api, 'ellen_dev', 'bobthephysicist')

# %%
# Out:
# {'AfollowsB': True, 'BfollowsA': True}

# %%
keyword = 'education'
journo_handles = journos.get_handles_by_keyword(keyword)
print(len(journo_handles))
# Out:
# 49

# %%
user_trial = batch_request_user_info(tw_api, journo_handles)

# %%
len(user_trial)
# Out:
# 49

# %%
def populate_user_df(user_data):
    '''
    Take a series of tweepy user objects and transform them into a dataframe.
    
    Params
    ------
    user_data : list
        List of tweepy.User objects 
    
    Returns
    -------
    user_df : Pandas DataFrame
        Cleaned dataframe with user data.
    '''
    df_fields = ['user_id', 'screen_name',  'name', 'location', 'user_description', 
              'user_friends_n', 'user_followers_n', 'prof_created_at', 'favourites_count', 
              'verified', 'statuses_count']
    
    API_fields = ['id', 'screen_name', 'name', 'location', 'description', 
                  'friends_count', 'followers_count', 'created_at', 'favourites_count',
                 'verified', 'statuses_count']
    # Go through tweepy user objects and pull relevant data into lists
    full_list = []
    for user in user_data:
        user_vars = vars(user)
        data_list = [user_vars[field] for field in API_fields]
        full_list.append(data_list)
    # Translate data list into dataframe
    user_df = pd.DataFrame(full_list, columns=df_fields)
    # Additional cleaning of data in dataframe
    user_df['screen_name'] = user_df['screen_name'].str.lower()
    
    return user_df

# %%
test_df = populate_user_df(user_trial)

# %%
test_df.head(10)
# Out:
#      user_id      screen_name              name  \
# 0  314483971    alicewoolley1     Alice Woolley
# 1      13265         richarda     Richard Adams
# 2   46346940    sarahjewell21      Sarah Jewell
# 3  360667680  camillahmturner    Camilla Turner
# 4  391350249       suzigodson       suzi godson
# 5   87180626    rosiedbennett  Rosemary Bennett
# 6  330204167            ajack       Andrew Jack
# 7  127830995       kitchenbee        Bee Wilson
# 8  163242135         tamcohen      Tamara Cohen
# 9  224592767  branwenjeffreys  branwen jeffreys
#
#                         location  \
# 0  London, Surrey, Oxon, Arizona
# 1                 United Kingdom
# 2                         London
# 3                         London
# 4                London, England
# 5                         London
# 6                         London
# 7
# 8                    Westminster
# 9      LONDON a great world city
#
#                                     user_description  user_friends_n  \
# 0  Journalist. Editor of Education Guardian. Euro...             976
# 1  The Guardian's education editor - email me at ...            2577
# 2  Commercial features editor at Guardian News an...             655
# 3  Education Editor @Telegraph. Views are my own....            2277
# 4  Sex columnist for The Times newspaper. Co-foun...            4562
# 5  Education Editor for The Times. Unhealthy obse...            1347
# 6  Global education editor @FT Free schools acces...            1456
# 7  I write about food. And other things. Books in...            1691
# 8  Political Correspondent, Sky News. And at the ...            2174
# 9  BBC Education Editor - runs slow, reads faster...            2223
#
#    user_followers_n     prof_created_at  favourites_count  verified  \
# 0             20847 2011-06-10 10:12:52             26062      True
# 1             18926 2006-11-20 15:41:59              9682      True
# 2               354 2009-06-11 08:39:23                14     False
# 3              4008 2011-08-23 15:35:56                29     False
# 4              5143 2011-10-15 12:49:11              4191      True
# 5              9408 2009-11-03 12:40:13              4929      True
# 6              6781 2011-07-06 08:11:24               780      True
# 7             26193 2010-03-30 11:01:02             21976     False
# 8             34231 2010-07-05 22:44:21               788      True
# 9             27869 2010-12-09 11:20:55                52     False
#
#    statuses_count
# 0           33836
# 1           31175
# 2            1597
# 3            2993
# 4            4713
# 5            3941
# 6            6101
# 7           23872
# 8           10800
# 9           13027

# %%
cyber_df = pd.read_csv('../data/raw/cyber_journalist_friends_2.csv')

# %%
cyber_df.head()
# Out:
#       screen_name          friend
# 0  jennystrasburg    RobaHusseini
# 1  jennystrasburg  HashemOsseiran
# 2  jennystrasburg     liveanthony
# 3  jennystrasburg      EliseKapNM
# 4  jennystrasburg      adam_tooze

# %%
friends = list(cyber_df['friend'].unique())

# %%
friends_profiles = batch_request_user_info(tw_api, friends)

# %%
friends_df = populate_user_df(friends_profiles)

# %%
friends_df.head(20)
# Out:
#        user_id      screen_name                          name  \
# 0    363675945     robahusseini          Roba El Husseini ربى
# 1   2546033492   hashemosseiran               Hashem Osseiran
# 2    179178993      liveanthony              Anthony Galloway
# 3   1325420790       elisekapnm                  Elise Kaplan
# 4   3311286493       adam_tooze                    Adam Tooze
# 5    117543420    bartongellman                Barton Gellman
# 6     25598396     nhannahjones                 Ida Bae Wells
# 7   2433239862    southeastrocu                        SEROCU
# 8    282288629           euirim                   Euirim Choi
# 9    216602554    davecolephoto                     Dave Cole
# 10  2906666380          ncscgov                          NCSC
# 11    17632630    chris_kenning                 Chris Kenning
# 12   260314736       mjcontrera              Jessica Contrera
# 13    92854623     hannahdreier                 Hannah Dreier
# 14     8200072  brodyismefriend          Steven BRODY Stevens
# 15    29607664       adamliptak                   Adam Liptak
# 16   159947350        wildfranz                    Franz Wild
# 17  2863580894  nocontextpawnee  out of context parks and rec
# 18     9349172            craiu                   Costin Raiu
# 19   178003933            k_sec              Kurt Baumgartner
#
#                          location  \
# 0                         Lebanon
# 1                          Beirut
# 2                    New York, NY
# 3         Albuquerque, New Mexico
# 4                    New York, NY
# 5          New York & on the road
# 6        nhannahjones@nytimes.com
# 7                      South East
# 8                    Stanford, CA
# 9                    New York, NY
# 10
# 11
# 12  jessica.contrera@washpost.com
# 13                Washington, DC
# 14    Desert Southwest Energies 🦂
# 15
# 16                London, England
# 17                     Pawnee, IN
# 18                      Bucharest
# 19                    Boulder, CO
#
#                                      user_description  user_friends_n  \
# 0   Journalist @AFP covering Syria and Lebanon. Tw...            1244
# 1   Beirut-based @AFP journalist | Views my own | ...            1678
# 2   2x @TeamUSA triathlete | Global Head of Video ...             454
# 3   Bearer of bad news / criminal justice reporter...             741
# 4   History, economics, politics, climate. Columbi...            4931
# 5   Staff writer @TheAtlantic | Author 'Dark Mirro...             850
# 6   Reporter @nytmag covering race from 1619-prese...            2128
# 7   SEROCU is a collaboration between the Police F...             298
# 8   Covering tech for @WSJ | Computer Science @Sta...             471
# 9                   @WSJ Photo Editor. Pennsylvanian.            1691
# 10  Advancing Counterintelligence and Security Exc...             127
# 11  Journalist @courierjournal / @USAToday network...            1602
# 12  kid from Akron, collector of mugs & reporter o...            3270
# 13  Washington Post national reporter. Former ProP...            3137
# 14  Comedian from United States & The Valley. Stan...            5496
# 15      Supreme Court reporter for The New York Times             450
# 16  Editor/Reporter at the Bureau of Investigative...            1339
# 17               small, incremental change every day.              70
# 18  Romanian antihacker from another planet; chief...            5959
# 19  principal security researcher - kaspersky GReA...             984
#
#     user_followers_n     prof_created_at  favourites_count  verified  \
# 0               2567 2011-08-28 14:13:43               649     False
# 1               2003 2014-06-04 12:41:32               493     False
# 2               2303 2010-08-16 18:06:32              3920      True
# 3               1566 2013-04-03 21:07:55              3552     False
# 4              95042 2015-08-10 07:35:58              6969     False
# 5              44841 2010-02-25 21:55:14                73      True
# 6             426025 2009-03-20 23:26:56             35251      True
# 7               1905 2014-04-08 07:51:13              1270     False
# 8                913 2011-04-14 22:52:08               579     False
# 9               2104 2010-11-17 06:05:25             12744     False
# 10             61268 2014-12-05 17:59:30                10      True
# 11              3093 2008-11-25 21:42:45               668      True
# 12             12767 2011-03-03 16:52:04              6056      True
# 13             54155 2009-11-26 23:04:23             20833      True
# 14             93360 2007-08-15 09:29:40             32224      True
# 15             76881 2009-04-08 01:47:31              1695      True
# 16              3195 2010-06-26 19:13:56               963     False
# 17            259042 2014-10-18 22:28:26             21290     False
# 18             28041 2007-10-10 11:17:38              5048      True
# 19              6856 2010-08-13 16:32:11              6817     False
#
#     statuses_count
# 0             1838
# 1             2381
# 2             2249
# 3             3074
# 4            36633
# 5             8181
# 6            74436
# 7             1689
# 8              484
# 9            12442
# 10            3287
# 11            2942
# 12             168
# 13            7164
# 14           76657
# 15            5259
# 16            7300
# 17            6145
# 18            6176
# 19           13400

# %%
friends_df.to_csv('../data/cleaned/cyber_user_profiles.csv', index=False)

# %%
friends_df['user_friends_n'].sum()
# Out:
# 53348775

# %% [markdown]
# ### Repeat for Education list

# %%
edu_df = pd.read_csv('../data/raw/education_journalist_friends.csv')

# %%
edu_df.head()
# Out:
#      screen_name          friend
# 0  alicewoolley1     FloraBarton
# 1  alicewoolley1  KateWilliamsme
# 2  alicewoolley1    AdviserSuper
# 3  alicewoolley1        SolGamsu
# 4  alicewoolley1        sarahcpr

# %%
edufriends = list(edu_df['friend'].unique())

# %%
edufriends_profiles = batch_request_user_info(tw_api, edufriends)

# %%
edufriends_df = populate_user_df(edufriends_profiles)

# %%
edufriends_df.head(20)
# Out:
#                 user_id     screen_name                   name  \
# 0             379197262     florabarton              Ms Barton
# 1             403075133  katewilliamsme     Prof Kate Williams
# 2    954089220200595460    advisersuper  Super Special Adviser
# 3            1169644826        solgamsu              Sol Gamsu
# 4              14642495        sarahcpr           Sarah Cooper
# 5             227258135    jason_arthur           Jason Arthur
# 6              18243837    rowennadavis          Rowenna Davis
# 7   1242887487313391616  ukcovid19stats            UK COVID-19
# 8             101326157        mannyawo       Emmanuel Awoyelu
# 9   1123199104815964160         ybtn_uk      #BlackLivesMatter
# 10  1099462352930553856  misterjjosephs         Johnoi Josephs
# 11             19884529         tompeck               Tom Peck
# 12            105838665     kategreensu             Kate Green
# 13             36780720     archiebland           Archie Bland
# 14            624820234      blahhcandy             Andy O 🇪🇺👍
# 15            230701906  jeffreykboakye         Jeffrey Boakye
# 16   890966204642447363        dee_delo   Danielle Lewis-Egonu
# 17           1189649689           sdupp              Stan Dupp
# 18  1164253063789600768   ravilious1942              Ravilious
# 19            384902603   stevehowell30           Steve Howell
#
#                    location  \
# 0            United Kingdom
# 1                    London
# 2               Westminster
# 3          Newcastle/Durham
# 4              Brooklyn, NY
# 5           London, England
# 6          Croydon, England
# 7            United Kingdom
# 8    Where legends are born
# 9
# 10          London, England
# 11  East, East, East London
# 12
# 13                   London
# 14
# 15           East Yorkshire
# 16                   London
# 17
# 18                Yorkshire
# 19   West Midlands, England
#
#                                      user_description  user_friends_n  \
# 0   Mother of two incredible children & Headteache...            1731
# 1   history prof. ❤️ in Wales. On TV for @CNN, @BB...            7837
# 2   A secret super special adviser for Gavin Willi...            1028
# 3   Lecturer @durhamsociology. Mostly researching,...            5485
# 4   writer / comedian / #blockedbytrump / wrote 10...            2990
# 5   Deputy Chief Exec (Interim) @iwill_campaign | ...            1745
# 6   English teacher @harrisinvictus, Labour activi...             832
# 7   #Coronavirus dashboard for the #UnitedKingdom ...             122
# 8   Educator/SENCo/Governor - Director at @thereac...            1050
# 9   Connecting young black teachers in England thr...             693
# 10  Believer | Teacher | I cook in my spare time |...             387
# 11  Political Sketch Writer and columnist at the @...            2074
# 12  Labour MP for Stretford & Urmston and Shadow E...            1545
# 13  Senior reporter, the Guardian. Misuses 'litera...            5143
# 14                                                TBC             195
# 15  Father. Teacher. Author: HOLD TIGHT, BLACK, LI...            1559
# 16            Executive Head Teacher-Mother-Cat Owner             853
# 17  Cartoonist for Schools Week. Baron Adonis says...            1695
# 18  This account is a tribute to the work of Briti...             115
# 19  Proud dad to 2 brilliant children and husband ...            4026
#
#     user_followers_n     prof_created_at  favourites_count  verified  \
# 0               6682 2011-09-24 14:54:23             19008     False
# 1             111839 2011-11-02 00:10:38            154608      True
# 2               1500 2018-01-18 20:32:51                47     False
# 3               5080 2013-02-11 18:18:55             25232     False
# 4            2221914 2008-05-03 23:30:29            139163      True
# 5               2999 2010-12-16 10:23:55             10439     False
# 6              14580 2008-12-19 15:40:29              1258     False
# 7              54386 2020-03-25 18:54:18              1700     False
# 8               4739 2010-01-02 22:11:46             25742     False
# 9               1531 2019-04-30 12:15:09               464     False
# 10               601 2019-02-24 00:13:46               982     False
# 11             78364 2009-02-02 00:07:51             13934      True
# 12             43945 2010-01-17 17:21:03              1378      True
# 13             18660 2009-04-30 21:38:52              3871      True
# 14                55 2012-07-02 16:47:57               706     False
# 15              7290 2010-12-26 11:44:31              9623     False
# 16               440 2017-07-28 16:04:31              1364     False
# 17              2561 2013-02-17 14:11:43             22783     False
# 18             15656 2019-08-21 19:09:12              8943     False
# 19              2947 2011-10-04 14:44:48              2153     False
#
#     statuses_count
# 0            10222
# 1            67901
# 2              978
# 3            18464
# 4            37518
# 5             6021
# 6             5115
# 7             4982
# 8            77797
# 9             3513
# 10             575
# 11           61354
# 12           15311
# 13           32240
# 14            1075
# 15           16841
# 16             860
# 17           10841
# 18            1085
# 19           14015

# %%
edufriends_df.to_csv('../data/cleaned/education_user_profiles.csv', index=False)

# %%
edufriends_df['user_friends_n'].sum()
# Out:
# 160718652

# %% [markdown]
# ### Repeat for Politics list

# %%
poli_df = pd.read_csv('../data/raw/politic_journalist_friends.csv')

# %%
keyword = 'political'
journo_handles = journos.get_handles_by_keyword(keyword)
print(len(journo_handles))
# Out:
# 236

# %%
poli_df.shape
# Out:
# (875304, 2)

# %%
poli_df_subset = poli_df[poli_df['screen_name'].isin(journo_handles)]

# %%
poli_df_subset['screen_name'] = poli_df_subset['screen_name'].str.lower()
# Out:
# C:\Users\rwhwe\.conda\envs\S2DS\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
poli_df_subset.head()
# Out:
#        screen_name           friend
# 0  shippersunbound      danharris80
# 1  shippersunbound  NatalieElphicke
# 2  shippersunbound     KermodeMovie
# 3  shippersunbound       JoshNorris
# 4  shippersunbound        timlevell

# %%
polifriends = list(poli_df_subset['friend'].unique())

# %%
polifriends_profiles = batch_request_user_info(tw_api, polifriends)

# %%
polifriends_df = populate_user_df(polifriends_profiles)

# %%
polifriends_df.head(20)
# Out:
#                 user_id      screen_name                       name  \
# 0             458470994      danharris80                 Dan Harris
# 1            1154535918  natalieelphicke        Natalie Elphicke MP
# 2             111323990     kermodemovie               Mark Kermode
# 3              19752348       joshnorris                Josh Norris
# 4              19530491        timlevell                 Tim Levell
# 5              26668729      john_hudson                John Hudson
# 6            1325563478  ianblackford_mp              Ian Blackford
# 7              46427981     meggiefoster              Meggie Foster
# 8   1263091525417910273         yngvlgrn                        MLC
# 9   1261218289797271557   journoworldcup  Journalist World Cup 2020
# 10           2426899705     dchilcottfco          Dominick Chilcott
# 11            421223083     matt_hfoster     Matt Honeycombe-Foster
# 12           2382227424         drrosena       Dr Rosena Allin-Khan
# 13   738100836857958400   thejonnyreilly            Jonathan Reilly
# 14             14431283      jilllawless               Jill Lawless
# 15  1214108358292041728       nj_timothy               Nick Timothy
# 16           3092429597      nicktorfaen     Nick Thomas-Symonds MP
# 17            518660800   anneliesedodds            Anneliese Dodds
# 18            240682562    chrisduncania               Chris Duncan
# 19             50612517  richardvaughan1            Richard Vaughan
#
#                        location  \
# 0
# 1                  Dover & Deal
# 2   last aisle seat on the left
# 3
# 4                    Manchester
# 5              Washington, D.C.
# 6                  Isle of Skye
# 7               London, England
# 8
# 9
# 10              Ankara, Türkiye
# 11   Westminster via Nottingham
# 12                       London
# 13              London, England
# 14
# 15
# 16                      Torfaen
# 17              Oxford, England
# 18                          WFH
# 19                       London
#
#                                      user_description  user_friends_n  \
# 0   Editor-in-Chief, @Fantasypros/@BettingProsNFL....             767
# 1   Conservative Member of Parliament for Dover & ...             945
# 2   Author HOW DOES IT FEEL? @ScalaRadio Sat.  @Ob...            1130
# 3   The early bird gets first dibs at the salad ba...            1268
# 4   Programme Director of @TimesRadio. Formerly @B...            4398
# 5   I cover diplomacy & national security for The ...            3111
# 6   Member of parliament for Ross, Skye and Lochab...             383
# 7   I can't believe I can't believe it's not butte...             873
# 8                            here to have a good time            1066
# 9                    64 Journalists, only one winner.              80
# 10  Twitter account of British Ambassador to Turke...             773
# 11  Acting editor @PoliticsHome, joining @POLITICO...            2870
# 12  🌹Labour MP for #Tooting 🗣Shadow Cabinet Minist...            6597
# 13  Political Correspondent @TheSun. Former Gen Re...            2160
# 14  I cover culture, society and politics for The ...            2570
# 15  Author of Remaking One Nation: The Future of C...             969
# 16  Shadow Home Secretary and Welsh Labour MP for ...            4366
# 17  Shadow Chancellor. Labour and Cooperative MP f...             896
# 18  CEO UK Publishing, Bauer Media. Ex-Newscorp. V...            1358
# 19  Political correspondent for @theipaper. All tw...            1484
#
#     user_followers_n     prof_created_at  favourites_count  verified  \
# 0              12864 2012-01-08 16:09:06              1322     False
# 1               5214 2013-02-06 17:05:48              1293      True
# 2             581297 2010-02-04 14:41:34             14909      True
# 3              71388 2009-01-30 03:37:38              1062      True
# 4               4230 2009-01-26 11:58:14              3960     False
# 5              62620 2009-03-26 02:39:24              8823      True
# 6              93396 2013-04-03 22:16:28              7774      True
# 7             118936 2009-06-11 16:42:02                68     False
# 8                779 2020-05-20 12:57:48             14205     False
# 9               1254 2020-05-15 08:54:13                 0     False
# 10             29172 2014-04-04 07:57:25               482      True
# 11              6737 2011-11-25 17:23:49             19114     False
# 12            173775 2014-03-10 14:32:15              8399      True
# 13              1545 2016-06-01 20:12:07              1449      True
# 14              4698 2008-04-18 09:04:08              4265      True
# 15              9318 2020-01-06 08:56:17              2692     False
# 16             26136 2015-03-16 15:31:47              7162      True
# 17             48146 2012-03-08 16:44:32              3991      True
# 18              3154 2011-01-20 14:01:22             11276      True
# 19              5396 2009-06-25 10:46:42              1536      True
#
#     statuses_count
# 0             6263
# 1             1802
# 2            40754
# 3            22972
# 4             4212
# 5            21137
# 6            14649
# 7             2876
# 8             4543
# 9               72
# 10            2785
# 11           26708
# 12           12917
# 13            1361
# 14           13925
# 15            2148
# 16            7769
# 17            6607
# 18           10670
# 19            8532

# %%
polifriends_df.to_csv('../data/cleaned/political_user_profiles.csv', index=False)

# %%
polifriends_df['user_friends_n'].sum()
# Out:
# 323372678

# %%
poli_df_subset.to_csv('../data/cleaned/political_journalist_friends.csv', index=False)

# %%
len(polifriends)
# Out:
# 148408
